# %%
from functionpath import SubfieldsInAI

# %%
SubfieldsInAI.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
from functionpath import OddEven

# %%
OddEven.OddEven()
# Out:
# Enter a number: 52452
# 52452 is Even number

# %%
from functionpath import ElegiblityForMarriage

# %%
ElegiblityForMarriage.Elegible()
# Out:
# Your Gender: Male
# Your Age: 20
# NOT ELIGIBLE

# %%
from functionpath import tenthresult

# %%
tenthresult.tenthmark()
# Out:
# Subject1= 98
# Subject2= 87
# Subject3= 95
# Subject4= 95
# Subject5= 93
# Total : 468
# Percentage : 93.6

# %%
from functionpath import triangleFm

# %%
triangleFm.triangle()
# Out:
# Height: 32
# Breadth: 34
# Area formula:(Height*Breadth)/2
# Area of Triangle: 544.0
# Height1: 2
# Height2: 4
# Breadth1: 4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 10
