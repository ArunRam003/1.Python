# %%
import pickle
sc = pickle.load(open("DATA_SET_SVR.sav", 'rb'))

# %%
preinput=sc.transform([[1300,6000,4000,0,1]])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 preinput=sc.transform([[1300,6000,4000,0,1]])
#
# AttributeError: 'SVR' object has no attribute 'transform'

# %%
import pickle
loaded_model=pickle.load(open("Finalized_model_SVR.sav",'rb'))
result=loaded_model.predict(preinput)

# %%
result
