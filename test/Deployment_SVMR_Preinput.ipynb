# %%
import pickle
loaded_model=pickle.load(open("DATA_SET_SVR.sav",'rb'))

# %%
preinput=sc.transform([[1300,12000,4000,0,1]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 preinput=sc.transform([[1300,12000,4000,0,1]])
#
# NameError: name 'sc' is not defined

# %%
import pickle
loaded_model=pickle.load(open("Finalized_model_SVR.sav",'rb'))
result=loaded_model.predict(preinput)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 import pickle
#       2 loaded_model=pickle.load(open("Finalized_model_SVR.sav",'rb'))
# ----> 3 result=loaded_model.predict(preinput)
#
# NameError: name 'preinput' is not defined
