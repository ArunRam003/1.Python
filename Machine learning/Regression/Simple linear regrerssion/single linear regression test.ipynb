# %%
import pandas as pd

# %%
dataset=pd.read_csv("salary_Data.csv")

# %%
independent=dataset[["YearsExperience"]]

# %%
dependent=dataset[["Salary"]]

# %%
X_train,X_test,y_train,y_test=train_test_split(independent, dependent, test_size=0.30,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 X_train,X_test,y_train,y_test=train_test_split(independent, dependent, test_size=0.30,random_state=0)
#
# NameError: name 'train_test_split' is not defined

# %%
regressor=regressor.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 regressor=regressor.fit(X_train,y_train)
#
# NameError: name 'regressor' is not defined

# %%
weight=regressor.coef_
weight
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 weight=regressor.coef_
#       2 weight
#
# NameError: name 'regressor' is not defined

# %%
bais=regressor.intercept_
bais
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 bais=regressor.intercept_
#       2 bais
#
# NameError: name 'regressor' is not defined

# %%
y_pred=regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score

# %%
result=regressor.predict([[25]])

# %%
result
