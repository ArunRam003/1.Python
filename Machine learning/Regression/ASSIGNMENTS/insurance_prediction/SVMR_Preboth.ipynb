# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[[ 'charges']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.preprocessing import StandardScaler
scy=StandardScaler()
y_train=scy.fit_transform(y_train)
y_test=scy.transform(y_test)

# %%
from sklearn.svm import SVR
regressor=SVR(kernel="linear",C=100)
regressor.fit(X_train,y_train)
# Out:
# C:\Users\Arun\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(C=100, kernel='linear')

# %%
import pickle
pickle.dump(sc,open("DATA_SET_SVR_bothsc.sav",'wb'))
pickle.dump(scy,open("DATA_SET_SVR_bothscy.sav",'wb'))

# %%
y_pred=regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.7582842895028473

# %%
import pickle
filename="Finalized_model_SVR_Preboth.sav"

# %%
pickle.dump(regressor,open(filename,'wb'))

# %%
preinput=sc.transform([[6000,25000,5000,0,1]])
# Out:
# C:\Users\Arun\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
preinput
# Out:
# array([[ 4.25597559e+02,  4.00645439e+03,  4.15347440e+03,
#         -9.76765571e-01,  1.98149332e+00]])

# %%
loaded_model=pickle.load(open("Finalized_model_SVR_Preboth.sav",'rb'))
result=loaded_model.predict(preinput)

# %%
filename
# Out:
# 'Finalized_model_SVR_Preboth.sav'

# %%
result
# Out:
# array([496.74355684])

# %%
preoutput=scy.inverse_transform([result])

# %%
preoutput
# Out:
# array([[5911447.87749553]])
