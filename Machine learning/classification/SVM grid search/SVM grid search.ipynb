# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0         True
# 1    15810944   35            20000          0         True
# 2    15668575   26            43000          0        False
# 3    15603246   27            57000          0        False
# 4    15804002   19            76000          0         True
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1        False
# 396  15706071   51            23000          1         True
# 397  15654296   50            20000          1        False
# 398  15755018   36            33000          0         True
# 399  15594041   49            36000          1        False
#
# [400 rows x 5 columns]

# %%
dataset.dtypes
# Out:
# User ID            int64
# Age                int64
# EstimatedSalary    int64
# Purchased          int64
# Gender_Male         bool
# dtype: object

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
dataset.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
indep = dataset[['Gender_Male', 'Age', 'EstimatedSalary']]
dep = dataset[['Purchased']]

# %%
indep.shape
# Out:
# (400, 3)

# %%
dep
# Out:
#      Purchased
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 395          1
# 396          1
# 397          1
# 398          0
# 399          1
#
# [400 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(indep,dep,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.svm import SVC

# %%
from sklearn.model_selection import GridSearchCV
param_grid={'kernel':['linear','rbf','poly','sigmoid'],
           'gamma':['auto','scale'],
           'C':[10,100,1000,2000]}

grid=GridSearchCV(SVC(probability=True),param_grid,refit=True,verbose=3,cv=5,n_jobs=-1,scoring='f1_weighted')

grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# C:\Users\Arun\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv=5, estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000], 'gamma': ['auto', 'scale'],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(X_test)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,grid_predictions)
from sklearn.metrics import classification_report
clf_report=classification_report(y_test,grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for the best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for the best parameter {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}: 0.9100355779243318

# %%
print("The confustion Matrix:\n",cm)
# Out:
# The confustion Matrix:
#  [[80  5]
#  [ 7 42]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93        85
#            1       0.89      0.86      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.91      0.90      0.90       134
# weighted avg       0.91      0.91      0.91       134

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# np.float64(0.9539015606242497)

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.026433      0.001718         0.016057        0.001548       10
# 1        0.023787      0.003505         0.018381        0.001547       10
# 2        0.025216      0.002878         0.016304        0.001344       10
# 3        0.016564      0.001779         0.014636        0.000908       10
# 4        0.022899      0.002256         0.015071        0.002074       10
# 5        0.016740      0.003416         0.014130        0.001278       10
# 6        0.021652      0.001111         0.013898        0.001028       10
# 7        0.015561      0.003418         0.013652        0.002488       10
# 8        0.067520      0.005177         0.014886        0.001062      100
# 9        0.023110      0.004393         0.013695        0.001426      100
# 10       0.098889      0.018404         0.014872        0.003535      100
# 11       0.015806      0.003595         0.016806        0.001861      100
# 12       0.079854      0.003214         0.013776        0.001864      100
# 13       0.026909      0.002720         0.015722        0.002304      100
# 14       0.089761      0.026307         0.015380        0.002555      100
# 15       0.019031      0.004327         0.015282        0.002587      100
# 16       0.455987      0.071857         0.012664        0.001639     1000
# 17       0.071853      0.012731         0.013636        0.001858     1000
# 18       0.527809      0.078031         0.012013        0.001028     1000
# 19       0.016505      0.001356         0.012612        0.000605     1000
# 20       0.436382      0.054857         0.011869        0.000481     1000
# 21       0.068005      0.008600         0.014218        0.002686     1000
# 22       0.744059      0.372050         0.012448        0.001952     1000
# 23       0.024301      0.017814         0.013566        0.001764     1000
# 24       0.858043      0.198511         0.011322        0.000434     2000
# 25       0.102248      0.019055         0.013160        0.001638     2000
# 26       1.226636      0.358618         0.015884        0.008676     2000
# 27       0.014716      0.002099         0.013943        0.004971     2000
# 28       0.865680      0.223113         0.013777        0.004594     2000
# 29       0.101015      0.013602         0.012538        0.000325     2000
# 30       1.208814      0.261796         0.011115        0.003515     2000
# 31       0.012837      0.001147         0.011224        0.000849     2000
#
#    param_gamma param_kernel  \
# 0         auto       linear
# 1         auto          rbf
# 2         auto         poly
# 3         auto      sigmoid
# 4        scale       linear
# 5        scale          rbf
# 6        scale         poly
# 7        scale      sigmoid
# 8         auto       linear
# 9         auto          rbf
# 10        auto         poly
# 11        auto      sigmoid
# 12       scale       linear
# 13       scale          rbf
# 14       scale         poly
# 15       scale      sigmoid
# 16        auto       linear
# 17        auto          rbf
# 18        auto         poly
# 19        auto      sigmoid
# 20       scale       linear
# 21       scale          rbf
# 22       scale         poly
# 23       scale      sigmoid
# 24        auto       linear
# 25        auto          rbf
# 26        auto         poly
# 27        auto      sigmoid
# 28       scale       linear
# 29       scale          rbf
# 30       scale         poly
# 31       scale      sigmoid
#
#                                                params  split0_test_score  \
# 0      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 1         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.867478
# 2        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.799620
# 3     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.762677
# 4     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 5        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.867478
# 6       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.799620
# 7    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.762677
# 8     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 9        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.867478
# 10      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 11   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.808927
# 12   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 13      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.867478
# 14     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 15  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.808927
# 16   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 17      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.826263
# 18     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 19  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.791752
# 20  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 21     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.847141
# 22    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.808927
# 24   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 25      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.826263
# 26     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 27  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.791752
# 28  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 29     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.826263
# 30    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 31  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...           0.808927
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.790949           0.698235           0.923510
# 1            0.886792           0.869709           0.944161
# 2            0.808392           0.787943           0.924528
# 3            0.738916           0.655795           0.796284
# 4            0.790949           0.698235           0.923510
# 5            0.886792           0.869709           0.944161
# 6            0.808392           0.787943           0.924528
# 7            0.738916           0.753180           0.778067
# 8            0.790949           0.698235           0.923510
# 9            0.886792           0.870362           0.944161
# 10           0.787284           0.766556           0.924528
# 11           0.714931           0.633719           0.718497
# 12           0.790949           0.698235           0.923510
# 13           0.886792           0.870362           0.944161
# 14           0.787284           0.766556           0.924528
# 15           0.714931           0.698113           0.796284
# 16           0.790949           0.698235           0.923510
# 17           0.866968           0.851527           0.925272
# 18           0.765553           0.766556           0.924528
# 19           0.714931           0.698113           0.796284
# 20           0.790949           0.698235           0.923510
# 21           0.866968           0.851527           0.925272
# 22           0.765553           0.766556           0.924528
# 23           0.714931           0.698113           0.796284
# 24           0.790949           0.698235           0.923510
# 25           0.866968           0.851527           0.886792
# 26           0.765553           0.766556           0.924528
# 27           0.714931           0.698113           0.796284
# 28           0.790949           0.698235           0.923510
# 29           0.866968           0.851527           0.886792
# 30           0.765553           0.766556           0.924528
# 31           0.714931           0.698113           0.796284
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.901744         0.818146        0.083619               17
# 1            0.943041         0.902236        0.034431                3
# 2            0.901744         0.844445        0.056918                9
# 3            0.766556         0.744045        0.047743               31
# 4            0.901744         0.818146        0.083619               17
# 5            0.943041         0.902236        0.034431                3
# 6            0.901744         0.844445        0.056918                9
# 7            0.766556         0.759879        0.013172               25
# 8            0.901744         0.818146        0.083619               17
# 9            0.943041         0.902367        0.034308                1
# 10           0.901744         0.840441        0.062370               11
# 11           0.766556         0.728526        0.058625               32
# 12           0.901744         0.818146        0.083619               17
# 13           0.943041         0.902367        0.034308                1
# 14           0.901744         0.840441        0.062370               11
# 15           0.766556         0.756962        0.043745               26
# 16           0.901744         0.818146        0.083619               17
# 17           0.923510         0.878708        0.039503                6
# 18           0.901744         0.836095        0.066541               13
# 19           0.766556         0.753527        0.040048               29
# 20           0.901744         0.818146        0.083619               17
# 21           0.923510         0.882884        0.034529                5
# 22           0.901744         0.836095        0.066541               13
# 23           0.766556         0.756962        0.043745               26
# 24           0.901744         0.818146        0.083619               17
# 25           0.903610         0.867032        0.026948                7
# 26           0.901744         0.836095        0.066541               13
# 27           0.766556         0.753527        0.040048               29
# 28           0.901744         0.818146        0.083619               17
# 29           0.903610         0.867032        0.026948                7
# 30           0.901744         0.836095        0.066541               13
# 31           0.766556         0.756962        0.043745               26

# %%
age_input=float(input('Age:'))
salary_input=float(input('EstimatedSalary'))
sex_male_input=int(input('Sex_Male 0 or 1:'))
# Out:
# Age: 30
# EstimatedSalary 30000
# Sex_Male 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,salary_input,sex_male_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[1]
