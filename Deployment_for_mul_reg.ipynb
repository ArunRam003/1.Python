# %%
import pickle
loaded_model=pickle.load(open("multiple_linear_regression_50_startups.sav",'rb'))
result=loaded_model.predict([[38558.51,82982.09,174999.30,False,False]])
# Out:
# C:\Users\Arun\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[80830.86589239]])
