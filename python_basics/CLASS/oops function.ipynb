# %%
list=[10,25,30,66,78,1,63,3]

# %%
def counting():    
    for num in list:
        if(num<15):
            print("1")
        elif(num<50):
            print("2")
        elif(num<75):
            print("3")
        else:
            print("4")

# %%
counting()
# Out:
# 1
# 2
# 2
# 3
# 4
# 1
# 3
# 1

# %%
def countings():   
    num=int(input("Enter the num:"))
       
    if(num<15):
        print("1")
        cate="1"
    elif(num<50):
        print("2")
        cate="2"
    elif(num<75): 
        print("3")
        cate="3"
    else:
        print("4")
        cate="4" 
    return cate

# %%
cate=counting()
# Out:
# 1

# %%
if(cate=="2"):
    print("yes")
else:
    print("no")
# Out:
# no

# %%
def counting():        
        if(num<15):
            print("1")
            cate="1"
        elif(num<50):
            print("2")
            cate="2"
        elif(num<75):
            print("3")
            cate="3"
        else:
            print("4")
            cate="4"
        return cate

# %%
num=int(input("Enter the num:"))
numcate=counting()
# Out:
# Enter the num: 10
# 1

# %%
if(numcate=="3"):
    print("yes")
else:
    print("no")
# Out:
# no

# %%
counting()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 counting()
#
# NameError: name 'counting' is not defined

# %%
class action():

    num=int(input("Enter the num:"))

    def counting():        
        if(num<15):
            print("1")
            cate="1"
        elif(num<50):
            print("2")
            cate="2"
        elif(num<75):
            print("3")
            cate="3"
        else:
            print("4")
            cate="4"
        return cate
# Out:
# Enter the num: 50

# %%
action.counting()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 action.counting()
#
# Cell In[19], line 6, in action.counting()
#       5 def counting():
# ----> 6     if(num<15):
#       7         print("1")
#       8         cate="1"
#
# NameError: name 'num' is not defined

# %%
class ElegiblityForMarriage():
    def Elegible():
        gender=input("Your Gender:")
        age=int(input("Your Age:"))
        if(gender=='Male'):
          if(age >=21):
            print('ELIGIBLE')
          else:
            print('NOT ELIGIBLE')
        elif(gender=='Female'):
          if(age >18):
            print('ELIGIBLE')
          else:
            print('NOT ELIGIBLE')
        else:
          print('INVALID')

# %%
ElegiblityForMarriage.Elegible()
# Out:
# Your Gender: Male
# Your Age: 22
# ELIGIBLE
