# %%
#function, and list out the items in the list 

def Subfields():
    list=["Sub-fields in AI are:","Machine Learning","Neural Networks","Vision","Robotics",
"Speech Processing","Natural Language Processing"]
    for Subfields in list:
        print(Subfields)

# %%
Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
# Create a function that checks whether the given number is Odd or Even
def OddEven():
    NUM=int(input("Enter a number:"))
    if((NUM%2)==0):
        print(NUM,"is Even number ")
    else:
        print(NUM,"is Odd number ")

# %%
OddEven()
# Out:
# Enter a number: 52452
# 52452 is Even number

# %%
# Create a function that tells elegibility of marriage for male and female according to their age limit like 21 for male and 18 for female

def Elegible():
    Gender=input("Your Gender:")
    Age=int(input("Your Age:"))
    
    if(Age>21):
        print("ELIGIBLE")
        message="ELIGIBLE"
    else:
        print("NOT ELIGIBLE")
        message="NOT ELIGIBLE"

    return message

# %%
message=Elegible()
# Out:
# Your Gender: Male
# Your Age: 20
# NOT ELIGIBLE

# %%
#if we need to go more step with above out we can use message.

# %%
# calculate the percentage of your 10th mark 

Subject1=int(input("Subject1=")) 
Subject2=int(input("Subject2=")) 
Subject3=int(input("Subject3=")) 
Subject4=int(input("Subject4=")) 
Subject5=int(input("Subject5=")) 
add=Subject1+Subject2+Subject3+Subject4+Subject5
Percentage=(add/5)
print("Total :",add,)
print("Percentage :",Percentage)
# Out:
# Subject1= 98
# Subject2= 87
# Subject3= 95
# Subject4= 95
# Subject5= 93
# Total : 468
# Percentage : 93.6

# %%
#print area and perimeter of triangle using class and functions

def triangle(): 
    Height=int(input("Height:"))
    Breadth=int(input("Breadth:"))
    Area=(Height*Breadth)/2
    
    print("Area formula:(Height*Breadth)/2")
    print("Area of Triangle:",Area)
    
    Height1=int(input("Height1:"))
    Height2=int(input("Height2:"))
    Breadth1=int(input("Breadth1:"))
    Perimeter=Height1+Height2+Breadth1

    print("Perimeter formula: Height1+Height2+Breadth ")
    print("Perimeter of Triangle:",Perimeter)

# %%
triangle()
# Out:
# Height: 32
# Breadth: 34
# Area formula:(Height*Breadth)/2
# Area of Triangle: 544.0
# Height1: 2
# Height2: 4
# Breadth1: 4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 10
