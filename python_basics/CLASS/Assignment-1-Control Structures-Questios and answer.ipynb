# %%
print("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
Title=input("Enter the name:")
# Out:
# Enter the name: Welcome to Assignment-1

# %%
Num1=10
Num2=30
add=(Num1+Num2)
print("Num1=10")
print("Num2=30")
print("add =",add)
# Out:
# Num1=10
# Num2=30
# add = 40

# %%
Num1=int(input("Enter the Num1:"))
Num2=int(input("Enter the Num2:"))
add=(Num1+Num2)
print("add =",add)
# Out:
# Enter the Num1: 10
# Enter the Num2: 30
# add = 40

# %%
 #Body Mass Index

# %%
Enter the BMI Index:34
Very Overweight

# %%
person=34 
if(person<18.5):
    print("Underweight")
elif(person<24.9):
    print("Normal range")
elif(person<29.9):
    print("Overweight")
else:
    print("Very Overweight")
# Out:
# Very Overweight
