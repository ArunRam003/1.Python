# %%
class action():

    

    def apple():
        num=int(input("Enter the num:"))
        if(num<15):
            print("1")
            cate="1"
        elif(num<50):
            print("2")
            cate="2"
        elif(num<75):
            print("3")
            cate="3"
        else:
            print("4")
            cate="4"
        return cate
    def orange():
        num1=int(input("Enter the num1:"))
        if(num1<15):
            print("1")
            cate="1"
        elif(num1<50):
            print("2")
            cate="2"
        elif(num1<75):
            print("3")
            cate="3"
        else:
            print("4")
            cate="4"
        return cate

# %%
action.orange()
# Out:
# Enter the num1: 76
# 4
# '4'
