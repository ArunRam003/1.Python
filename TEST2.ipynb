# %%
lists=[5,10,15,20,25,30,50]

# %%
age=int(input("enter the num:"))
# Out:
# enter the num: 60

# %%
for temp in lists:
    print(temp)
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 50

# %%
if (age<18):
    print("s")
elif(age<30):
    print("m")
elif(age<50):
    print("xl")   
elif(age<70):
    print("xxl")    
else:
    print("xxxl")
# Out:
# xxl

# %%
for age in lists:
    if (age<18):
        print("s")
    elif(age<30):
        print("m")
    elif(age<50):
        print("xl")   
    elif(age<70):
        print("xxl")    
    else:
        print("xxxl")
# Out:
# s
# s
# s
# m
# m
# xl
# xxl

# %%
num=int(input("enter the number"))
if((num%2)==0):
    print("even number")
else:
    print("odd number")
# Out:
# enter the number 25
# odd number

# %%
for temp in range(0,9):
    print(temp)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
for num in range(50,100,10):
    print(num)
# Out:
# 50
# 60
# 70
# 80
# 90
